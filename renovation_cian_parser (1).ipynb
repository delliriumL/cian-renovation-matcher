# %% [markdown]
# # Поиск объявлений по реновации, размещенных на ЦИАН
# Мы хотим найти на ЦИАН квартиры, которые продаются в домах из программы реновации. Зачем? Во-первых, это может быть полезно тем, кто следит за темой реновации - например, хочет купить квартиру в уже утверждённом доме. Во-вторых, в этом сегменте может быть особая динамика по ценам, спросу и предложениям - и если выделить эти объявления, можно сделать отдельный срез рынка.
#
# Проблема в том, что напрямую на ЦИАН такие квартиры часто не помечаются, а иногда и наоборот - пишут, что квартира подпадает под реновацию, но на самом деле не находится в реестре. Поэтому мы идём в обход: берём официальный список домов из реестра реновации, парсим объявления с ЦИАН и пытаемся сопоставить адреса - несмотря на то, что в обоих источниках они записаны по-разному. Это требует немного нормализации, парсинга и частичных сравнений, но в итоге даёт вполне рабочую выборку квартир по реновации.

# %% [markdown]
# ## 0) Установка зависимостей
#
# Запускаем Playwright и необходимые пакеты. Если вы перезапускаете среду, повторите эту ячейку.

# %%
# %pip -q install playwright pandas openpyxl requests
# !python -m playwright install chromium
# Out:
#                                        Адрес ext_status  district  \
# 0             1-й Ботанический проезд, дом 1       None      2556
# 1             1-й Ботанический проезд, дом 3       None      2556
# 2            1-й Ботанический проезд, дом 3А       None      2556
# 3  1-й Волоколамский проезд, дом 7, корпус 1  destroyed      2483
# 4  1-й Волоколамский проезд, дом 7, корпус 2  destroyed      2483
#
#                coords
# 0   [55.8502, 37.634]
# 1   [55.851, 37.6343]
# 2  [55.8511, 37.6336]
# 3  [55.8008, 37.4918]
# 4  [55.8007, 37.4911]

# %% [markdown]
# ## 1) Импорты и базовые константы
# Держим настройки в одном месте: город для парсинга адресов и параметры запроса к официальному реестру реновации.

# %%
from __future__ import annotations
import re, asyncio
from typing import Iterable, List, Optional, Tuple

import requests
import pandas as pd

CITY = "москва"

URL = "https://fr.mos.ru/pokupka-nedvizhimosti-dlya-vseh/ajax.php"
PARAMS = {"status[]": "OLD", "pagesize": 100000, "map": "ren"}
HEADERS = {"User-Agent": "Mozilla/5.0"}

# %% [markdown]
# ## 2) Загрузка реестра реновации
# Реестр реновации мы тянем напрямую с сайта fr.mos.ru, где он подгружается динамически через XHR-запрос к ajax.php. Если открыть DevTools в браузере (F12), перейти на вкладку Network → XHR/Fetch и перезагрузить страницу, можно отследить этот запрос и скопировать его параметры. Мы делаем ровно то же самое - обращаемся к тому же эндпоинту, с теми же параметрами и заголовком, чтобы получить сырой JSON с нужными нам объектами.
#
# После запроса достаём список домов (items) из ключей ["objects"]["items"], и на его основе формируем датафрейм с нужными полями: адрес, статус, район и координаты. Это ещё не нормализованные адреса, просто черновой реестр - но уже можно посмотреть, что в нём лежит.

# %%
resp = requests.get(URL, params=PARAMS, headers=HEADERS, timeout=30)
resp.raise_for_status()
items = resp.json()["objects"]["items"]

ren_df = pd.DataFrame([
    {
        "Адрес": d.get("name"),
        "ext_status": d.get("ext_status"),
        "district": d.get("district"),
        "coords": d.get("coords"),
    }
    for d in items
])

ren_df.head(5)
# Out:
#                                        Адрес ext_status  district  \
# 0             1-й Ботанический проезд, дом 1       None      2556
# 1             1-й Ботанический проезд, дом 3       None      2556
# 2            1-й Ботанический проезд, дом 3А       None      2556
# 3  1-й Волоколамский проезд, дом 7, корпус 1  destroyed      2483
# 4  1-й Волоколамский проезд, дом 7, корпус 2  destroyed      2483
#
#                coords
# 0   [55.8502, 37.634]
# 1   [55.851, 37.6343]
# 2  [55.8511, 37.6336]
# 3  [55.8008, 37.4918]
# 4  [55.8007, 37.4911]

# %% [markdown]
# ## 3) Парсинг объявлений ЦИАН через Playwright
#
# Используем Playwright (Chromium в headless-режиме): открываем страницы, ждём появления карточек и читаем DOM по CSS-селекторам. Почему так: у ЦИАН нет открытого простого JSON-эндпоинта для всего списка, а HTML стабилен под эти селекторы.

# %%
from playwright.async_api import async_playwright

async def parse_cian(pages: int = 2, max_price: int = 7_000_000, save_path: Optional[str] = None) -> pd.DataFrame:
    data = []
    url_template = (
        "https://www.cian.ru/cat.php?engine_version=2&p={page}&deal_type=sale&offer_type=flat&region=1&maxprice={max_price}"
    )

    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        context = await browser.new_context()
        page = await context.new_page()

        for i in range(1, pages + 1):
            url = url_template.format(page=i, max_price=max_price)
            print("Смотрим:", url)
            await page.goto(url, wait_until="domcontentloaded")
            await page.wait_for_selector("article")
            offers = await page.query_selector_all("article")

            async def get_text(el, selector: str) -> str:
                node = await el.query_selector(selector)
                return (await node.inner_text()) if node else ""

            for offer in offers:
                title = await get_text(offer, "span[data-mark='OfferTitle']")
                price = await get_text(offer, "span[data-mark='MainPrice']")
                link_el = await offer.query_selector("a")
                link = await link_el.get_attribute("href") if link_el else ""

                geo_items = await offer.query_selector_all("a[data-name='GeoLabel']")
                address = ", ".join([await g.inner_text() for g in geo_items]) if geo_items else "—"

                data.append({"title": title, "price": price, "Адрес": address, "Ссылка на объявление": link})

        await browser.close()

    df = pd.DataFrame(data)
    if save_path:
        df.to_excel(save_path, index=False)
        print("Сохранено в", save_path)
    return df

# %% [markdown]
# ### 3.1) Запуск парсера
# В данном случае выбраны параметры максимальной цены 10.000.000 для квартир в городе Москве, но при желании код может быть дополнен под более специфичные требования.

# %%
offers_df = await parse_cian(pages=250, max_price=10_000_000, save_path="offers.xlsx")
offers_df.head(5)
# Out:
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=1&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=2&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=3&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=4&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=5&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=6&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=7&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=8&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=9&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=10&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=11&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=12&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=13&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=14&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=15&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=16&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=17&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=18&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=19&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=20&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=21&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=22&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=23&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=24&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=25&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=26&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=27&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=28&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=29&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=30&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=31&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=32&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=33&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=34&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=35&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=36&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=37&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=38&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=39&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=40&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=41&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=42&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=43&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=44&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=45&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=46&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=47&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=48&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=49&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=50&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=51&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=52&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=53&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=54&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=55&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=56&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=57&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=58&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=59&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=60&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=61&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=62&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=63&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=64&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=65&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=66&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=67&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=68&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=69&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=70&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=71&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=72&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=73&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=74&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=75&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=76&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=77&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=78&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=79&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=80&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=81&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=82&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=83&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=84&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=85&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=86&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=87&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=88&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=89&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=90&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=91&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=92&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=93&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=94&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=95&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=96&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=97&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=98&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=99&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=100&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=101&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=102&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=103&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=104&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=105&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=106&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=107&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=108&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=109&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=110&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=111&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=112&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=113&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=114&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=115&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=116&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=117&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=118&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=119&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=120&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=121&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=122&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=123&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=124&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=125&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=126&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=127&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=128&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=129&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=130&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=131&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=132&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=133&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=134&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=135&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=136&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=137&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=138&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=139&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=140&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=141&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=142&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=143&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=144&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=145&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=146&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=147&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=148&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=149&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=150&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=151&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=152&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=153&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=154&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=155&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=156&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=157&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=158&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=159&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=160&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=161&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=162&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=163&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=164&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=165&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=166&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=167&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=168&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=169&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=170&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=171&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=172&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=173&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=174&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=175&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=176&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=177&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=178&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=179&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=180&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=181&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=182&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=183&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=184&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=185&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=186&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=187&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=188&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=189&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=190&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=191&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=192&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=193&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=194&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=195&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=196&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=197&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=198&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=199&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=200&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=201&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=202&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=203&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=204&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=205&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=206&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=207&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=208&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=209&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=210&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=211&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=212&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=213&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=214&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=215&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=216&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=217&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=218&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=219&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=220&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=221&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=222&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=223&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=224&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=225&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=226&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=227&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=228&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=229&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=230&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=231&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=232&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=233&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=234&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=235&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=236&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=237&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=238&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=239&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=240&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=241&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=242&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=243&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=244&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=245&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=246&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=247&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=248&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=249&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Смотрим: https://www.cian.ru/cat.php?engine_version=2&p=250&deal_type=sale&offer_type=flat&region=1&maxprice=10000000
# Сохранено в offers.xlsx
#                                      title        price  \
# 0                  Апартаменты с White Box
# 1                   доступное жилье москва  4 822 000 ₽
# 2    Апартаменты-студия, 15,7 м², 1/5 этаж  4 330 000 ₽
# 3  Апартаменты-студия, 27,3 м², 19/23 этаж  9 229 502 ₽
# 4         Студия в ЖК "My Space в Ховрино"  6 510 000 ₽
#
#                                                Адрес  \
# 0  Москва, ЮАО, р-н Чертаново Южное, м. Аннино, В...
# 1  Москва, ЮВАО, р-н Кузьминки, м. Окская, Окская...
# 2  Москва, ЗАО, р-н Солнцево, м. Говорово, улица ...
# 3  Москва, СВАО, р-н Отрадное, м. Владыкино, Сигн...
# 4  Москва, САО, р-н Головинский, м. Моссельмаш, С...
#
#                        Ссылка на объявление
# 0  https://www.cian.ru/sale/flat/319308727/
# 1  https://www.cian.ru/sale/flat/306880520/
# 2  https://www.cian.ru/sale/flat/317909846/
# 3  https://www.cian.ru/sale/flat/309370579/
# 4  https://www.cian.ru/sale/flat/311088838/

# %%
offers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6993 entries, 0 to 6992
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 6993 non-null   object
#  1   price                 6993 non-null   object
#  2   Адрес                 6993 non-null   object
#  3   Ссылка на объявление  6993 non-null   object
# dtypes: object(4)
# memory usage: 218.7+ KB

# %% [markdown]
# ## 4) Поиск совпадений
#
# Чтобы сопоставить адреса из ЦИАН с адресами из реестра реновации, мы пошли не по самому прямолинейному пути. Дело в том, что в этих двух источниках один и тот же дом может быть записан совершенно по-разному: где-то указано "ул. 50 лет Октября, 2К2", где-то "улица 50 лет Октября, дом 2, корпус 1", а где-то всё это сопровождается районом, метро и жилым комплексом. В лоб такие строки не сравнишь.
#
# Поэтому мы упростили: для каждого адреса мы выделили название улицы и основной номер дома (без корпуса, строения и прочего). Если и улица, и номер дома совпадают - считаем, что это один и тот же дом. Такой подход не идеален, но позволяет выловить хотя бы базовые совпадения.
#
# В результате мы нашли 7 совпадений. Это немного, но объяснимо: адреса слишком разномастные, где-то мешает разница в корпусах, где-то - в написании улиц. Например, один адрес на ЦИАН может матчиться сразу с несколькими корпусами из реновации, а некоторые реальные совпадения могли не попасть в выборку из-за слишком разных формулировок.
#
# Что можно попробовать ещё:
# - нормализовать названия улиц (заменять "ул." на "улица", "пр-т" на "проспект" и т.п.);
# - учитывать корпус, если он явно указан;
# - дополнительно применять частичное или нестрогое сравнение (по токенам, как раньше), чтобы найти более неочевидные совпадения.
#
# Но даже такой базовый фильтр уже отсекает кучу нерелевантных адресов и даёт точку опоры для анализа.

# %%
def extract_base_house(addr: str) -> str:
    if pd.isna(addr):
        return None
    match = re.search(r'\b(\d{1,4})', addr)
    return match.group(1) if match else None
offers_df[["street", "house_base"]] = offers_df["Адрес"].apply(
    lambda x: pd.Series([*extract_street_and_house(x)] if extract_street_and_house(x) else (None, None))
)
offers_df["house_base"] = offers_df["Адрес"].map(extract_base_house)

ren_df[["street", "house_base"]] = ren_df["Адрес"].apply(
    lambda x: pd.Series([*extract_street_and_house(x)] if extract_street_and_house(x) else (None, None))
)
ren_df["house_base"] = ren_df["Адрес"].map(extract_base_house)
offers_clean = offers_df.dropna(subset=["street", "house_base"])
ren_clean = ren_df.dropna(subset=["street", "house_base"])

matches_base = offers_clean.merge(
    ren_clean[["street", "house_base", "Адрес", "district", "ext_status"]],
    on=["street", "house_base"],
    how="inner",
    suffixes=("_ЦИАН", "_реновация")
)

print(f"Найдено совпадений по базовому дому: {len(matches_base)}")
matches_base[["Адрес_ЦИАН", "Адрес_реновация", "Ссылка на объявление", "district", "ext_status"]].head(10)
# Out:
# Найдено совпадений по базовому дому: 7
#                                           Адрес_ЦИАН  \
# 0  Москва, СВАО, р-н Ростокино, м. Ростокино, про...
# 1  Москва, СВАО, р-н Ростокино, м. Ростокино, про...
# 2  Москва, ЮЗАО, р-н Котловка, м. Крымская, улица...
# 3  Москва, СЗАО, р-н Хорошево-Мневники, м. Бульва...
# 4  Москва, СЗАО, р-н Хорошево-Мневники, м. Бульва...
# 5  Москва, СЗАО, р-н Хорошево-Мневники, м. Бульва...
# 6  Москва, СЗАО, р-н Хорошево-Мневники, м. Бульва...
#
#                                Адрес_реновация  \
# 0                      проспект Мира, дом 188А
# 1                      проспект Мира, дом 188А
# 2     улица Дмитрия Ульянова, дом 47, корпус 2
# 3  бульвар Генерала Карбышева, дом 6, корпус 1
# 4  бульвар Генерала Карбышева, дом 6, корпус 2
# 5  бульвар Генерала Карбышева, дом 6, корпус 3
# 6  бульвар Генерала Карбышева, дом 6, корпус 4
#
#                        Ссылка на объявление  district ext_status
# 0  https://www.cian.ru/sale/flat/320292048/      2569       None
# 1  https://www.cian.ru/sale/flat/320292048/      2569       None
# 2  https://www.cian.ru/sale/flat/321183005/      2550  destroyed
# 3  https://www.cian.ru/sale/flat/319591523/      2507       None
# 4  https://www.cian.ru/sale/flat/319591523/      2507       None
# 5  https://www.cian.ru/sale/flat/319591523/      2507       None
# 6  https://www.cian.ru/sale/flat/319591523/      2507       None

# %%
list(matches_base['Адрес_ЦИАН'][0:20])
# Out:
# ['Москва, СВАО, р-н Ростокино, м. Ростокино, проспект Мира, 188Бк2',
#  'Москва, СВАО, р-н Ростокино, м. Ростокино, проспект Мира, 188Бк2',
#  'Москва, ЮЗАО, р-н Котловка, м. Крымская, улица Дмитрия Ульянова, 47',
#  'Москва, СЗАО, р-н Хорошево-Мневники, м. Бульвар Генерала Карбышева, Живописная улица, 6К3',
#  'Москва, СЗАО, р-н Хорошево-Мневники, м. Бульвар Генерала Карбышева, Живописная улица, 6К3',
#  'Москва, СЗАО, р-н Хорошево-Мневники, м. Бульвар Генерала Карбышева, Живописная улица, 6К3',
#  'Москва, СЗАО, р-н Хорошево-Мневники, м. Бульвар Генерала Карбышева, Живописная улица, 6К3']

# %%
list(matches_base['Адрес_реновация'][0:20])
# Out:
# ['проспект Мира, дом 188А',
#  'проспект Мира, дом 188А',
#  'улица Дмитрия Ульянова, дом 47, корпус 2',
#  'бульвар Генерала Карбышева, дом 6, корпус 1',
#  'бульвар Генерала Карбышева, дом 6, корпус 2',
#  'бульвар Генерала Карбышева, дом 6, корпус 3',
#  'бульвар Генерала Карбышева, дом 6, корпус 4']

# %% [markdown]
# ## 5) Экспорт результатов
# Сохраняем результат в эксельку для удобного просмотра и взаимодействия.

# %%
with pd.ExcelWriter("cian_renovation_matches.xlsx", engine="openpyxl") as xls:
    matches_base.to_excel(xls, sheet_name="base_match", index=False)
print("Готово")
# Out:
# Готово
